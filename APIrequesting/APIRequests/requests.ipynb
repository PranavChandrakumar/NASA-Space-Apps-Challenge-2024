# %%
import requests
from dotenv import load_dotenv
import os
import requests as r

# %%
load_dotenv()
api = 'https://appeears.earthdatacloud.nasa.gov/api/'
user = os.getenv('NASA_USERNAME')
password = os.getenv('NASA_PASSWORD')
token_response = r.post(f'{api}login', auth=(user, password)).json()

# %%
# create the task request
task = {
    'task_type': 'point',
    'task_name': 'Task1',
    'params': {
         'dates': [
         {
             'startDate': '01-01-2024',
             'endDate': '01-02-2024'
         }],
         'layers': [
         {
             'product': 'L09.002',
             'layer': 'SR_B3'
         }],
         'coordinates': [
         {
             'latitude': 42,
             'longitude': -72
         }]
    }
}

# submit the task request
token = token_response['token']
response = requests.post(
    'https://appeears.earthdatacloud.nasa.gov/api/task', 
    json=task, 
    headers={'Authorization': 'Bearer {0}'.format(token)})
task_response = response.json()
task_id = task_response['task_id']
print(task_response)
# Out:
# {'task_id': 'bbd9d6c2-6aae-4b6d-b199-0a808d58fd74', 'status': 'pending'}

# %%
response = requests.get(
    'https://appeears.earthdatacloud.nasa.gov/api/task/{0}'.format(task_id), 
    headers={'Authorization': 'Bearer {0}'.format(token)}
)
task_response = response.json()
task_response
# Out:
# {'tier': 2,
#  'error': None,
#  'params': {'dates': [{'endDate': '01-02-2024', 'startDate': '01-01-2024'}],
#   'layers': [{'layer': 'SR_B3', 'product': 'L09.002'}],
#   'coordinates': [{'latitude': 42, 'longitude': -72}]},
#  'status': 'done',
#  'crashed': False,
#  'created': '2024-10-05T18:57:29.290908',
#  'task_id': 'bbd9d6c2-6aae-4b6d-b199-0a808d58fd74',
#  'updated': '2024-10-05T18:57:55.860754',
#  'user_id': 'heliosspaceapp@gmail.com',
#  'attempts': 1,
#  'estimate': {'request_size': 1, 'request_memory': 1},
#  'retry_at': None,
#  'completed': '2024-10-05T18:57:55.841370',
#  'has_swath': False,
#  'task_name': 'Task1',
#  'task_type': 'point',
#  'api_version': 'v1',
#  'svc_version': '3.63',
#  'web_version': None,
#  'has_nsidc_daac': False,
#  'expires_on': '2024-11-04T18:57:55.860754'}

# %%
# download the data
response = requests.get(
    'https://appeears.earthdatacloud.nasa.gov/explore/bbd9d6c2-6aae-4b6d-b199-0a808d58fd74',
    headers={'Authorization': 'Bearer {0}'.format(token)}
)
print(response.content.decode('utf-8'))

# with open('data.zip', 'wb') as f:
#     f.write(response.content)

# # unzip the data
# import zipfile
# with zipfile.ZipFile('data.zip', 'r') as zip_ref:
#     zip_ref.extractall('data')
# Out:
# <!doctype html>
# <html lang="en" data-critters-container>
#   <head>
#     <!-- Google Tag Manager -->
#     <script>var dataLayer=window.dataLayer=window.dataLayer||[];
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-WNP7MLF');</script>
#     <!-- End Google Tag Manager -->
#      <!-- Earth Data Status App -->
#     <script src="https://status.earthdata.nasa.gov/assets/banner_widget.js"></script>
#     <!-- End  Earth Data Status App -->
#
#     <title>A&rho;&rho;EEARS</title>
#     <base href="/">
#
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
# ...

# %%
# download the data
response = requests.get(
    'https://appeears.earthdatacloud.nasa.gov/download/bbd9d6c2-6aae-4b6d-b199-0a808d58fd74',
    headers={'Authorization': 'Bearer {0}'.format(token)}
)
print(response.content.decode('utf-8'))

# with open('data.zip', 'wb') as f:
#     f.write(response.content)

# # unzip the data
# import zipfile
# with zipfile.ZipFile('data.zip', 'r') as zip_ref:
#     zip_ref.extractall('data')
# Out:
# <!doctype html>
# <html lang="en" data-critters-container>
#   <head>
#     <!-- Google Tag Manager -->
#     <script>var dataLayer=window.dataLayer=window.dataLayer||[];
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-WNP7MLF');</script>
#     <!-- End Google Tag Manager -->
#      <!-- Earth Data Status App -->
#     <script src="https://status.earthdata.nasa.gov/assets/banner_widget.js"></script>
#     <!-- End  Earth Data Status App -->
#
#     <title>A&rho;&rho;EEARS</title>
#     <base href="/">
#
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
# ...
