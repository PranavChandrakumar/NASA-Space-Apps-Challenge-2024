#
# [304 rows x 0 columns]

# %%
df_resampled = df.resample('D').count()
df_resampled
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/x7/l4fzcmr5641_9hgkws623m3r0000gn/T/ipykernel_78226/37218298.py in ?()
# ----> 1 df_resampled = df.resample('D').count()
#       2 df_resampled
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/resample.py in ?(self)
#    1097     @doc(GroupBy.count)
#    1098     def count(self):
# -> 1099         result = self._downsample("count")
#    1100         if not len(self.ax):
#    1101             if self._selected_obj.ndim == 1:
#    1102                 result = type(self._selected_obj)(
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/resample.py in ?(self, how, **kwargs)
#    1295         # we are downsampling
#    1296         # we want to call the actual grouper method here
#    1297         result = obj.groupby(self.grouper, axis=self.axis).aggregate(how, **kwargs)
#    1298
# -> 1299         return self._wrap_result(result)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/resample.py in ?(self, result)
#    1358     def _wrap_result(self, result):
# -> 1359         result = super()._wrap_result(result)
#    1360
#    1361         # we may have a different kind that we were asked originally
#    1362         # convert if needed
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/resample.py in ?(self, result)
#     469             isinstance(result, ABCDataFrame)
#     470             and result.empty
#     471             and not isinstance(result.index, PeriodIndex)
#     472         ):
# --> 473             result = result.set_index(
#     474                 _asfreq_compat(obj.index[:0], freq=self.freq), append=True
#     475             )
#     476
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5914
#    5915             if len(arrays[-1]) != len(self):
#    5916                 # check newest element against length of calling frame, since
#    5917                 # ensure_index_from_sequences would not raise for append=False.
# -> 5918                 raise ValueError(
#    5919                     f"Length mismatch: Expected {len(self)} rows, "
#    5920                     f"received array of length {len(arrays[-1])}"
#    5921                 )
#
# ValueError: Length mismatch: Expected 4200 rows, received array of length 0

# %%
from statsmodels.tsa.arima.model import ARIMA

# Define the ARIMA model (replace p, d, q with your selected values)
model = ARIMA(daily_passovers, order=(p, d, q))
model_fit = model.fit()

# Print model summary
print(model_fit.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 4
#       1 from statsmodels.tsa.arima.model import ARIMA
#       3 # Define the ARIMA model (replace p, d, q with your selected values)
# ----> 4 model = ARIMA(daily_passovers, order=(p, d, q))
#       5 model_fit = model.fit()
#       7 # Print model summary
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/arima/model.py:158, in ARIMA.__init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     151     trend = 'n'
#     153 # Construct the specification
#     154 # (don't pass specific values of enforce stationarity/invertibility,
#     155 # because we don't actually want to restrict the estimators based on
#     156 # this criteria. Instead, we'll just make sure that the parameter
#     157 # estimates from those methods satisfy the criteria.)
# --> 158 self._spec_arima = SARIMAXSpecification(
#     159     endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     160     trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#     161     concentrate_scale=concentrate_scale, trend_offset=trend_offset,
#     162     dates=dates, freq=freq, missing=missing,
#     163     validate_specification=validate_specification)
#     164 exog = self._spec_arima._model.data.orig_exog
#     166 # Raise an error if we have a constant in an integrated model
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/arima/specification.py:454, in SARIMAXSpecification.__init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     451 # Validate endog shape
#     452 if (validate_specification and not faux_endog and
#     453         self.endog.ndim > 1 and self.endog.shape[1] > 1):
# --> 454     raise ValueError('SARIMAX models require univariate `endog`. Got'
#     455                      ' shape %s.' % str(self.endog.shape))
#     457 self._has_missing = (
#     458     None if faux_endog else np.any(np.isnan(self.endog)))
#
# ValueError: SARIMAX models require univariate `endog`. Got shape (4200, 76).

# %%
result = adfuller(df.index.to_series())
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: 5.643556238866284
# p-value: 1.0

# %% [markdown]
# since the augmented dickey-fuller test (adf) has a p-value of 1.0 > 0.05, we have insufficient evidence to reject the null hypothesis that the series is non-stationary
#
# thus, we differentiate:

# %%
if 'value' not in df.columns:
    raise ValueError("The specified column 'value' does not exist in the DataFrame.")
endog = df['value']  # Ensure you have a univariate time series
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 if 'value' not in df.columns:
# ----> 2     raise ValueError("The specified column 'value' does not exist in the DataFrame.")
#       3 endog = df['value']  # Ensure you have a univariate time series
#
# ValueError: The specified column 'value' does not exist in the DataFrame.

# %%
p = 1
d = 1
q = 1

model = ARIMA(df_diff, order=(p, d, q))
model_fit = model.fit()
forecast = model_fit.forecast(steps=1)
predicted_date = df.index[-1] + pd.Timedelta(days=forecast[0])
print("Predicted next date:", predicted_date)

plt.figure(figsize=(10, 5))
plt.plot(df.index, df.values, label='Historical Data')
plt.axvline(x=predicted_date, color='r', linestyle='--', label='Predicted Next Date')
plt.legend()
plt.title('Date Prediction using ARIMA')
plt.xlabel('Date')
plt.ylabel('Value')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 7
#       4 d = 1  # degree of differencing
#       5 q = 1  # order of MA
# ----> 7 model = ARIMA(df_diff, order=(p, d, q))
#       8 model_fit = model.fit()
#      10 # Step 5: Make predictions
#      11 # Forecast the next date
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/arima/model.py:158, in ARIMA.__init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     151     trend = 'n'
#     153 # Construct the specification
#     154 # (don't pass specific values of enforce stationarity/invertibility,
#     155 # because we don't actually want to restrict the estimators based on
#     156 # this criteria. Instead, we'll just make sure that the parameter
#     157 # estimates from those methods satisfy the criteria.)
# --> 158 self._spec_arima = SARIMAXSpecification(
#     159     endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     160     trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#     161     concentrate_scale=concentrate_scale, trend_offset=trend_offset,
#     162     dates=dates, freq=freq, missing=missing,
#     163     validate_specification=validate_specification)
#     164 exog = self._spec_arima._model.data.orig_exog
#     166 # Raise an error if we have a constant in an integrated model
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/arima/specification.py:454, in SARIMAXSpecification.__init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     451 # Validate endog shape
#     452 if (validate_specification and not faux_endog and
#     453         self.endog.ndim > 1 and self.endog.shape[1] > 1):
# --> 454     raise ValueError('SARIMAX models require univariate `endog`. Got'
#     455                      ' shape %s.' % str(self.endog.shape))
#     457 self._has_missing = (
#     458     None if faux_endog else np.any(np.isnan(self.endog)))
#
# ValueError: SARIMAX models require univariate `endog`. Got shape (0, 15).
